# %%
pip install nbmerge
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6393 sha256=34e3e991f451d4f16a951e6d11eef03008d0af46145ae2241275740fd49e3a21
#   Stored in directory: /Users/annagarbo1/Library/Caches/pip/wheels/0b/a8/31/4ae563f674b488c82ee72cfe0f86487c21532db97ae910b264
# Successfully built nbmerge
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nbmerge

timedelayproject = nbmerge.merge_notebooks(file_paths=['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge\ BHBH-3.ipynb','/Users/annagarbo1/Desktop/astro/time\ merge\ machine\ learning-4.ipynb'])
timedelaypoject.export_notebook('timedelayproject.ipynb')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_b/dwnrhdgd0y7_7nj2zgdrqt6m0000gq/T/ipykernel_23376/4112263404.py in <module>
#       1 import nbmerge
#       2
# ----> 3 timedelayproject = nbmerge.merge_notebooks(file_paths=['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge\ BHBH-3.ipynb','/Users/annagarbo1/Desktop/astro/time\ merge\ machine\ learning-4.ipynb'])
#       4 timedelaypoject.export_notebook('timedelayproject.ipynb')
#
# TypeError: merge_notebooks() missing 1 required positional argument: 'base_dir'

# %%
import nbmerge

notebook_paths = ['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge BHBH-3.ipynb', '/Users/annagarbo1/Desktop/astro/time merge machine learning-4.ipynb']
timedelayproject = nbmerge.merge_notebooks(notebook_paths)
timedelayproject.export_notebook('timedelayproject.ipynb')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_b/dwnrhdgd0y7_7nj2zgdrqt6m0000gq/T/ipykernel_23376/4049174675.py in <module>
#       2
#       3 notebook_paths = ['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge BHBH-3.ipynb', '/Users/annagarbo1/Desktop/astro/time merge machine learning-4.ipynb']
# ----> 4 timedelayproject = nbmerge.merge_notebooks(notebook_paths)
#       5 timedelayproject.export_notebook('timedelayproject.ipynb')
#
# TypeError: merge_notebooks() missing 1 required positional argument: 'file_paths'

# %%
import nbmerge

notebook_paths = ['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge BHBH-3.ipynb', '/Users/annagarbo1/Desktop/astro/time merge machine learning-4.ipynb']
output_dir = '/Users/annagarbo1/Desktop/astro'
timedelayproject = nbmerge.merge_notebooks(notebook_paths, output_dir)
timedelayproject.export_notebook('timedelayproject.ipynb')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /var/folders/_b/dwnrhdgd0y7_7nj2zgdrqt6m0000gq/T/ipykernel_23376/319257851.py in <module>
#       3 notebook_paths = ['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge BHBH-3.ipynb', '/Users/annagarbo1/Desktop/astro/time merge machine learning-4.ipynb']
#       4 output_dir = '/Users/annagarbo1/Desktop/astro'
# ----> 5 timedelayproject = nbmerge.merge_notebooks(notebook_paths, output_dir)
#       6 timedelayproject.export_notebook('timedelayproject.ipynb')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nbmerge/__init__.py in merge_notebooks(base_dir, file_paths, verbose, boundary_key)
#      67
#      68     for path in file_paths:
# ---> 69         with io.open(path, 'r', encoding='utf-8') as fp:
#      70             if verbose:
# ...

# %%
import nbmerge

notebook_paths = ['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge BHBH-3.ipynb', '/Users/annagarbo1/Desktop/astro/time merge machine learning-4.ipynb']
output_path = '/Users/annagarbo1/Desktop/astro/timedelayproject.ipynb'
timedelayproject = nbmerge.merge_notebooks(notebook_paths, output_path)
timedelayproject.export_notebook()
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /var/folders/_b/dwnrhdgd0y7_7nj2zgdrqt6m0000gq/T/ipykernel_23376/2578831473.py in <module>
#       3 notebook_paths = ['/Users/annagarbo1/Desktop/astro/Data_distributions_1.ipynb', '/Users/annagarbo1/Desktop/astro/Time_Merge BHBH-3.ipynb', '/Users/annagarbo1/Desktop/astro/time merge machine learning-4.ipynb']
#       4 output_path = '/Users/annagarbo1/Desktop/astro/timedelayproject.ipynb'
# ----> 5 timedelayproject = nbmerge.merge_notebooks(notebook_paths, output_path)
#       6 timedelayproject.export_notebook()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nbmerge/__init__.py in merge_notebooks(base_dir, file_paths, verbose, boundary_key)
#      67
#      68     for path in file_paths:
# ---> 69         with io.open(path, 'r', encoding='utf-8') as fp:
#      70             if verbose:
# ...

# %%
nbmerge Data_distributions_1.ipynb Time_Merge_BHBH_3.ipynb time_merge_machine_learning_4.ipynb > time_delay_project.ipynb
# Out:
#   File "/var/folders/_b/dwnrhdgd0y7_7nj2zgdrqt6m0000gq/T/ipykernel_23376/1748763441.py", line 1
#     nbmerge Data_distributions_1.ipynb Time_Merge_BHBH_3.ipynb time_merge_machine_learning_4.ipynb > time_delay_project.ipynb
#             ^
# SyntaxError: invalid syntax

# %%
import nbmerge

notebook_paths = ['Data_distributions_1.ipynb', 'Time_Merge_BHBH_3.ipynb', 'time_merge_machine_learning_4.ipynb']
output_path = 'time_delay_project.ipynb'
timedelayproject = nbmerge.merge_notebooks(notebook_paths, output_path)
timedelayproject.export_notebook()
